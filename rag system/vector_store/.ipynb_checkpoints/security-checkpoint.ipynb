# %%
import json
import shutil
from langchain_core.documents import Document
from langchain_ollama import OllamaEmbeddings
from langchain_chroma import Chroma
from pathlib import Path
from langchain_openai import OpenAIEmbeddings
import yaml
from langchain_core.embeddings import Embeddings 
import requests
from typing import List

# %%
sections_dir = Path("../data/json/security")
sections = []

for json_file in sorted(sections_dir.glob("*.json")):
    file_sections = json.loads(json_file.read_text(encoding="utf-8"))
    sections.extend(file_sections)
    print(f"Loaded {len(file_sections):>3} sections  ←  {json_file.name}")

print(f"\nTotal sections loaded: {len(sections)}")
# Out:
# Loaded  16 sections  ←  Accessing_Vault.json
# Loaded  13 sections  ←  Authenticating_a_User_with_LDAP.json
# Loaded  16 sections  ←  Enabling_Cross_Origin_Requests_for_a_RESTful_Web_Service.json
# Loaded  11 sections  ←  Securing_a_Web_Application.json
# Loaded  27 sections  ←  Spring_Boot_and_OAuth2.json
# Loaded  64 sections  ←  Spring_Security_and_Angular.json
# Loaded  14 sections  ←  Vault_Configuration.json
#
# Total sections loaded: 161

# %%
from itertools import groupby

CHUNK_SIZE            = 3
OVERLAP               = 1
STRIDE                = CHUNK_SIZE - OVERLAP   # = 2
MAX_CHARS_PER_SECTION = 800

# Boilerplate headings that appear identically in every Spring guide — skip them
SKIP_HEADINGS = {
    "What you'll build",
    "How to complete this guide",
    "What you'll need",
    "Summary"
}

chunks = []

# Sort ensures groupby works even if sections from different files are interleaved
sorted_sections = sorted(sections, key=lambda s: s["source"])

for source, group in groupby(sorted_sections, key=lambda s: s["source"]):
    doc_sections = [
        s for s in group
        if s["content"].strip() and s.get("heading", "") not in SKIP_HEADINGS
    ]
    for i in range(0, len(doc_sections), STRIDE):
        window = doc_sections[i : i + CHUNK_SIZE]
        content = "\n\n".join(
            (f"## {s['heading']}\n" if s["heading"] else "") +
            s["content"].strip()[:MAX_CHARS_PER_SECTION]
            for s in window
        )
        if not content.strip():
            continue
        chunks.append(Document(
            page_content=content,
            metadata={
                "headings": " | ".join(s["heading"] for s in window if s["heading"]),
                "title":    window[0]["title"],
                "source":   source,
            }
        ))

print(f"Created {len(chunks)} chunks  ({CHUNK_SIZE} sections/chunk, {OVERLAP} overlap)")
# Out:
# Created 78 chunks  (3 sections/chunk, 1 overlap)

# %%
chunks[0]
# Out:
# Document(metadata={'headings': 'What you’ll build | What you’ll need', 'title': 'Accessing Vault', 'source': 'https://spring.io/guides/gs/accessing-vault'}, page_content='This guide walks you through the process of using Spring Vault to build an application that loads secrets from HashiCorp Vault , a secrets management tool.\n\n## What you’ll build\nYou will load secrets stored in Vault and use the transit encryption backend.\n\n## What you’ll need\nAbout 15 minutes\nAbout 15 minutes\nA favorite text editor or IDE\nA favorite text editor or IDE\nJava 17 or later\nJava 17 or later\nGradle 7.5+ or Maven 3.5+\nGradle 7.5+ or Maven 3.5+\nYou can also import the code straight into your IDE: Spring Tool Suite (STS) IntelliJ IDEA VSCode\nYou can also import the code straight into your IDE:\nSpring Tool Suite (STS)\nSpring Tool Suite (STS)\nIntelliJ IDEA\nIntelliJ IDEA\nVSCode\nVSCode')

# %%
# import ollama

# response = ollama.embed(
#     model='nomic-embed-text',
#     input=chunks[0].page_content,
# )
# print(f"{response.embeddings} : {chunks[0].metadata['source']}")

# %%
with open("../config/setting.yaml") as f:
    key = yaml.safe_load(f)["llm"]["key"]

# %%
from openai import OpenAI
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key
634033203125, -0.0113983154296875, 0.010406494140625, 0.01000213623046875, 0.0235137939453125, 0.007598876953125, -0.047698974609375, 0.04339599609375, 0.007305145263671875, 0.01898193359375, -0.02081298828125, 0.00943756103515625, 0.0157623291015625, -0.0288848876953125, 0.033660888671875, 0.00968170166015625, 0.068359375, -0.00978851318359375, -0.03826904296875, -0.0041961669921875, -0.02508544921875, 0.005367279052734375, 0.01244354248046875, -0.0013170242309570312, -0.0118408203125, 0.030029296875, -0.0172576904296875, 0.0015726089477539062, -0.0168304443359375, -0.0172119140625, -0.0014390945434570312, -0.0216522216796875, -0.02880859375, 0.006305694580078125, 0.01922607421875, -0.0153350830078125, -0.0033588409423828125, 0.01311492919921875, 0.0286407470703125, 0.00921630859375, 0.04852294921875, -0.0209503173828125, 0.0204925537109375, 0.0190582275390625, -0.00836944580078125, -0.012542724609375, -0.0283355712890625, 0.031341552734375, 0.0260009765625, -0.044525146484375, -0.00384521484375, -0.0133819580078125, -0.0015773773193359375, 0.01497650146484375, -0.07098388671875, 0.04052734375, -0.04766845703125, -0.00948333740234375, -0.005950927734375, 0.0347 ...

# %%
# Clear old Chroma DB before re-embedding to avoid duplicates
shutil.rmtree("./chroma_db/security", ignore_errors=True)
print("Cleared old vector store.")
# Out:
# Cleared old vector store.

# %%
class OpenRouterEmbeddings(Embeddings):
    def __init__(self, model: str, api_key: str):
        self.model = model
        self.api_key = api_key

    def _embed(self, texts: List[str]) -> List[List[float]]:
        response = requests.post(
            "https://openrouter.ai/api/v1/embeddings",
            headers={"Authorization": f"Bearer {self.api_key}", "Content-Type": "application/json"},
            json={
                "model": self.model,
                "input": [
                    {"content": [{"type": "text", "text": t}]} for t in texts
                ],
                "encoding_format": "float"
            }
        )
        return [item["embedding"] for item in response.json()["data"]]

    def embed_documents(self, texts: List[str]) -> List[List[float]]:
        return self._embed(texts)

    def embed_query(self, text: str) -> List[float]:
        return self._embed([text])[0]

# %%
# Embed chunks and store in Chroma (persisted to disk)
embeddings = OpenRouterEmbeddings(
    model="nvidia/llama-nemotron-embed-vl-1b-v2:free",
    api_key=key
)

vectors_dir = "./chroma_db/security"

vector_store = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory=vectors_dir,
    collection_name="spring_security"
)

print(f"Stored {vector_store._collection.count()} embeddings in '{vectors_dir}'")
# Out:
# Stored 78 embeddings in './chroma_db/security'

# %%
# Sanity check: run a test similarity search
query = "how can i use Authentication with Spring Security"
results = vector_store.similarity_search(query, k=5)

for i, doc in enumerate(results):
    print(f"--- Result {i+1} ---")
    print(f"Source : {doc.metadata.get('source', 'unknown')}")
    print(f"Page   : {doc.metadata.get('page', '?')}")
    print(f"Content: {doc.page_content[:100]}")
    print()
# Out:
# --- Result 1 ---
# Source : https://spring.io/guides/gs/securing-web
# Page   : ?
# Content: ## Create an Unsecured Web Application
# Before you can apply security to a web application, you need
#
# --- Result 2 ---
# Source : https://spring.io/guides/tutorials/spring-boot-oauth2
# Page   : ?
# Content: ## Adding the Client Registration
# Then, you need to configure the client to point Google. Because Sp
#
# --- Result 3 ---
# Source : https://spring.io/guides/tutorials/spring-boot-oauth2
# Page   : ?
# Content: ## Adding an Error Message
# To support the retrieval of an error message, you’ll need to capture it w
