# %%
import json
import shutil
from langchain_core.documents import Document
from langchain_ollama import OllamaEmbeddings
from langchain_chroma import Chroma
from pathlib import Path
from langchain_openai import OpenAIEmbeddings
import yaml
from langchain_core.embeddings import Embeddings 
import requests
from typing import List

# %%
sections_dir = Path("../data/json/data_access")
sections = []

for json_file in sorted(sections_dir.glob("*.json")):
    file_sections = json.loads(json_file.read_text(encoding="utf-8"))
    sections.extend(file_sections)
    print(f"Loaded {len(file_sections):>3} sections  ←  {json_file.name}")
print(f"\nTotal sections loaded: {len(sections)}")
# Out:
# Loaded  17 sections  ←  Accessing_Data_Reactively_with_Redis.json
# Loaded  14 sections  ←  Accessing_Data_with_Cassandra.json
# Loaded  13 sections  ←  Accessing_Data_with_JPA.json
# Loaded  12 sections  ←  Accessing_Data_with_MongoDB.json
# Loaded  16 sections  ←  Accessing_data_with_MySQL.json
# Loaded  13 sections  ←  Accessing_Data_with_Neo4j.json
# Loaded  12 sections  ←  Accessing_data_with_R2DBC.json
# Loaded  11 sections  ←  Accessing_JPA_Data_with_REST.json
# Loaded  12 sections  ←  Accessing_MongoDB_Data_with_REST.json
# Loaded  10 sections  ←  Accessing_Relational_Data_using_JDBC_with_Spring.json
# Loaded   9 sections  ←  Managing_Transactions.json
#
# Total sections loaded: 139

# %%
from itertools import groupby

CHUNK_SIZE            = 3
OVERLAP               = 1
STRIDE                = CHUNK_SIZE - OVERLAP   # = 2
MAX_CHARS_PER_SECTION = 800

# Boilerplate headings that appear identically in every Spring guide — skip them
SKIP_HEADINGS = {
    "Starting with Spring Initializr",
    "What You Need",
    "How to complete this guide",
}

chunks = []

# Sort ensures groupby works even if sections from different files are interleaved
sorted_sections = sorted(sections, key=lambda s: s["source"])

for source, group in groupby(sorted_sections, key=lambda s: s["source"]):
    doc_sections = [
        s for s in group
        if s["content"].strip() and s.get("heading", "") not in SKIP_HEADINGS
    ]
    for i in range(0, len(doc_sections), STRIDE):
        window = doc_sections[i : i + CHUNK_SIZE]
        content = "\n\n".join(
            (f"## {s['heading']}\n" if s["heading"] else "") +
            s["content"].strip()[:MAX_CHARS_PER_SECTION]
            for s in window
        )
        if not content.strip():
            continue
        chunks.append(Document(
            page_content=content,
            metadata={
                "headings": " | ".join(s["heading"] for s in window if s["heading"]),
                "title":    window[0]["title"],
                "source":   source,
            }
        ))

print(f"Created {len(chunks)} chunks  ({CHUNK_SIZE} sections/chunk, {OVERLAP} overlap)")
# Out:
# Created 59 chunks  (3 sections/chunk, 1 overlap)

# %%
chunks[0]
# Out:
# Document(metadata={'headings': 'What You Will build | Setting up a Database', 'title': 'Accessing Data with Cassandra', 'source': 'https://spring.io/guides/gs/accessing-data-cassandra'}, page_content='This guide walks you through the process of using Spring Data Cassandra to build an application that stores data in and retrieves it from Apache Cassandra , a high-performance distributed database.\n\n## What You Will build\nYou will store and retrieve data from Apache Cassandra by using Spring Data Cassandra.\n\n## Setting up a Database\nBefore you can build the application, you need to set up a Cassandra database. Apache Cassandra is an open-source NoSQL data store optimized for fast reads and fast writes in large datasets. In the next subsections, you can choose between using DataStax Astra DB Cassandra-as-a-Service or running it locally on a Docker container. This guide describes how to use the free tier of DataStax Astra Cassandra-as-a-Service so you can create and store data in your Cassandra database in a matter of minutes.\nAdd the following properties in your application.properties ( src/main/resources/application.properties ) to configure Spring Data Cassandra:\nspring.cassandra.schema-action=CREATE_IF_NOT_EXISTS\nspring.cassandra.request.timeout=10s\nspring.cassandra.connection.connect-timeout=10s\nspring.cassandra.co')

# %%
import ollama

response = ollama.embed(
    model='nomic-embed-text',
    input=chunks[0].page_content,
)
print(f"{response.embeddings} : {chunks[0].metadata['source']}")
# Out:
# [[0.059809543, 0.04631697, -0.17938273, -0.03482624, 0.023362612, -0.05550568, 0.0103470385, 0.0068843463, -0.024365645, -0.04786128, -0.04293048, 0.009278206, 0.06924877, -0.015894653, -0.008680033, -0.0022421603, -0.009715727, -0.030771593, -0.02002831, 0.028440665, -0.0015772165, -0.061708536, 0.00063719647, -0.035681553, 0.057113457, 0.061881118, -0.033294097, 0.0059863897, -0.02911948, 0.030741237, 0.01833253, -0.017501842, -0.028734377, 0.007935214, -0.06358074, -0.052201916, -0.03281, -0.031089555, -0.011858279, -0.011732987, 0.042396598, -0.040474687, 0.02443701, -0.053519588, 0.04720544, 0.010829379, 0.0809627, -0.0062440243, 0.032916598, -0.045276556, -0.0073358933, 0.017237501, -0.010587336, -0.008968934, 0.02742132, 0.032852203, 0.047485236, 0.00021279056, -0.0033542267, -0.043565117, 0.14400771, 0.0551298, -0.027958306, 0.048337825, 0.05807851, 5.985787e-05, 0.003912028, 0.024502572, -0.008483917, -0.02374343, 0.026703874, -0.016709695, 0.024117492, -0.055235855, -0.031036505, 0.029426, -0.029986413, -0.027875766, 0.012700876, 0.048559338, 0.057948638, 0.0219743, 0.06067019, -0.0051824804, 0.043710254, -0.00067133916, -0.010871884, -0.01906089, -0.012615482, 0.06471317, -0.006201167, -0.026846187, -0.014433092, 0.00079699437, -0.058779158, 0.042051025, -0.0091309305, 0.039165836, -0.060986377, -0.012917462, -0.05331704, -0.030343184, -0.0025746485, 0.032627735, -0.012082305, 0.021947464, 0.0018154456, 0.011808387, -0.029931393, 0.006242335, -0.006883828, 0.024957499, 0.0008644374, 0.003222785, 0.019962315, -0.007952378, 0.060811337, -0.011451557, 0.0062419586, -0.011104447, -0.013232571, 0.012868163, 0.025451437, 0.02167602, 0.055904523, 0.022509994, -0.08367438, 0.0041491063, -0.008754012, -0.041835196, -0.023123257, -0.033730615, -0.054511752, 0.024975121, 0.027690867, 0.067405455, -0.030772522, -0.03339381, 0.0034354161, 0.0024767267, 0.016316542, 0.023507155, -0.037222918, -0.005686306, -0.0033811273, -0.025675114, -0.02338456, -0.030
875, -0.0181427001953125, 0.036651611328125, -0.0020160675048828125, 0.0018930435180664062, -0.034149169921875, 0.0208587646484375, 0.019744873046875, -0.00791168212890625, -0.0261993408203125, -0.00421142578125, 0.0065765380859375, 0.00618743896484375, 0.01053619384765625, 0.046875, -0.0027828216552734375, 0.0321044921875, -0.01013946533203125, -0.01447296142578125, -0.01142120361328125, -0.04241943359375, 0.005542755126953125, -0.01346588134765625, -0.006256103515625, -0.00676727294921875, 0.0163421630859375, 0.01523590087890625, 0.00760650634765625, -0.0358886718 ...

# %%
# Clear old Chroma DB before re-embedding to avoid duplicates
shutil.rmtree("./chroma_db/data_access", ignore_errors=True)
print("Cleared old vector store.")
# Out:
# Cleared old vector store.

# %%
class OpenRouterEmbeddings(Embeddings):
    def __init__(self, model: str, api_key: str):
        self.model = model
        self.api_key = api_key

    def _embed(self, texts: List[str]) -> List[List[float]]:
        response = requests.post(
            "https://openrouter.ai/api/v1/embeddings",
            headers={"Authorization": f"Bearer {self.api_key}", "Content-Type": "application/json"},
            json={
                "model": self.model,
                "input": [
                    {"content": [{"type": "text", "text": t}]} for t in texts
                ],
                "encoding_format": "float"
            }
        )
        return [item["embedding"] for item in response.json()["data"]]

    def embed_documents(self, texts: List[str]) -> List[List[float]]:
        return self._embed(texts)

    def embed_query(self, text: str) -> List[float]:
        return self._embed([text])[0]

# %%
# Embed chunks and store in Chroma (persisted to disk)
embeddings = OpenRouterEmbeddings(
    model="nvidia/llama-nemotron-embed-vl-1b-v2:free",
    api_key=key
)
vectors_dir = "./chroma_db/data_access"

vector_store = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory=vectors_dir,
    collection_name="spring_data_access"
)

print(f"Stored {vector_store._collection.count()} embeddings in '{vectors_dir}'")
# Out:
# Stored 59 embeddings in './chroma_db/data_access'

# %%
# Sanity check: run a test similarity search
query = "how to connect my spring app to MySQL database"
results = vector_store.similarity_search(query, k=5)

for i, doc in enumerate(results):
    print(f"--- Result {i+1} ---")
    print(f"Source : {doc.metadata.get('source', 'unknown')}")
    print(f"Page   : {doc.metadata.get('page', '?')}")
    print(f"Content: {doc.page_content[:100]}")
    print()
# Out:
# --- Result 1 ---
# Source : https://spring.io/guides/gs/accessing-data-mysql
# Page   : ?
# Content: This guide walks you through the process of creating a Spring application connected to a MySQL Datab
#
# --- Result 2 ---
# Source : https://spring.io/guides/gs/accessing-data-mysql
# Page   : ?
# Content: ## Summary
# Congratulations! You have just developed a Spring application that is bound to a MySQL da
#
# --- Result 3 ---
# Source : https://spring.io/guides/gs/accessing-data-mysql
# Page   : ?
# Content: ## Build an executable JAR
# You can run the application from the command line with Gradle or Maven. Y
#
# --- Result 4 ---
# Source : https://spring.io/guides/gs/accessing-data-mysql
# Page   : ?
# Content: ## How to Complete This Guide
# Like most Spring Getting Started guides you can start from scratch and
#
# --- Result 5 ---
# Source : https://spring.io/guides/gs/accessing-data-mysql
# Page   : ?
# Content: ## Create a Controller
# You need to create a controller to handle HTTP requests to your application,
