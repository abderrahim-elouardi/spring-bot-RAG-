# %%
import sys
from pathlib import Path

# Add rag system/ root to path so imports resolve correctly
sys.path.insert(0, str(Path('..').resolve()))

# %%
from rag.chain import ask

# %%
# Single question test
question = "How do I configure JPA with Spring Boot?"

answer = ask(question,k=3)
print(f"Q: {question}")
print(f"\nA: {answer}")
# Out:
# Q: How do I configure JPA with Spring Boot?
#
# A: **Configuring JPA in a Spring Boot application**
#
# 1. **Add the JPA starter (and a DB driver)**
#    ```xml
#    <!-- Maven -->
#    <dependency>
#        <groupId>org.springframework.boot</groupId>
#        <artifactId>spring-boot-starter-data-jpa</artifactId>
#    </dependency>
#
#    <!-- Example for H2 (in‑memory) -->
#    <dependency>
#        <groupId>com.h2database</groupId>
#        <artifactId>h2</artifactId>
#        <scope>runtime</scope>
#    </dependency>
#    ```
#    *or* with Gradle:
#    ```gradle
#    implementation 'org.springframework.boot:spring-boot-starter-data-jpa'
#    runtimeOnly 'com.h2database:h2'   // or mysql, postgresql, etc.
#    ```
#
# 2. **Configure the datasource** (`src/main/resources/application.properties` or `application.yml`)
#
#    ```properties
#    spring.datasource.url=jdbc:h2:mem:testdb          # change to your DB URL
#    spring.datasource.username=sa
#    spring.datasource.password=
# ...

# %%
# Test multiple questions across both collections
questions = [
    "How do I access data with MongoDB in Spring Boot?",
    "What is the difference between JPA and JDBC in Spring?",
    "How do I secure a Spring Boot REST API with OAuth2?",
    "How do I connect Spring Boot to a MySQL database?",
]

for q in questions:
    print(f"Q: {q}")
    print(f"A: {ask(q)}")
    print("-" * 60)
# Out:
# Q: How do I access data with MongoDB in Spring Boot?
# A: **Accessing data with MongoDB in a Spring Boot application**
#
# 1. **Add Spring Data MongoDB**
#    Use Spring Initializr (or add the dependency manually) so that `spring-boot-starter-data-mongodb` is on the classpath.
#
# 2. **Define a domain class (the document)**
#
#    ```java
#    package com.example.accessingdatamongodb;
#
#    import org.springframework.data.annotation.Id;
#    import org.jspecify.annotations.Nullable;
#
#    public class Customer {
#
#        @Id
#        public @Nullable String id;      // MongoDB’s _id field
#
#        public String firstName;
#        public String lastName;
#
#        public Customer() {}
#
#        public Customer(String firstName, String lastName) {
#            this.firstName = firstName;
#            this.lastName = lastName;
#        }
#
#        @Override
#        public String toString() {
#            return String.format(
# ...
